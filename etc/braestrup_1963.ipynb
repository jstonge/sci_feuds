# %%
import json
from mmda.types import Document

with open("braestrup_1963_gpt35turbo_clean.json") as f:
    dat = json.load(f)

with open('braestrup_1963_mmda.json') as f_in:
    doc_dict = json.load(f_in)
    doc = Document.from_json(doc_dict);
# Out:
# /home/jstonge/Documents/phd/side_quest/mmda/src/mmda/types/document.py:79: UserWarning: The annotations is empty for the field equations
#   warnings.warn(f"The annotations is empty for the field {field_name}")

# %%
display(doc.images[1])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=438x650>

# %%
dat
# Out:
# [{'text': 'In 1955 V. C. WYNNE-EDWARDS published a paper on low reproductive rates in certain birds.',
#   'sentiment_score': 6,
#   'mentions': [{'sentiment_score': 6,
#     'author_view': True,
#     'source': 'Braestrup',
#     'target': 'Wynne-Edwards'}]},
#  {'text': 'This paper contained important arguments against views expounded with, what appeared to be strict and irrefutable logic, by LACK (e.g. 1954) , viz., that in birds and mammals the number of eggs laid, or young born, corresponds to the largest number of offspring possible to raise.',
#   'sentiment_score': 5,
#   'mentions': [{'sentiment_score': 4,
#     'author_view': False,
#     'source': 'Braestrup',
#     'target': 'D. Lack'}]},
#  {'text': 'It may be argued and this is the line taken by W.-E.',
#   'sentiment_score': 5,
#   'mentions': [{'sentiment_score': 5,
#     'author_view': True,
#     'source': 'Braestrup',
#     'target': 'Wynne-Edwards'}]},
# ...
